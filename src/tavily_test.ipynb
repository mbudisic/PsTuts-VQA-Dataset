# %%
from tavily import TavilyClient
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from getpass import getpass
from dotenv import load_dotenv
load_dotenv()

def set_api_key_if_not_present(key_name, prompt_message=""):
    if len(prompt_message) == 0:
        prompt_message=key_name
    if key_name not in os.environ or not os.environ[key_name]:
        os.environ[key_name] = getpass.getpass(prompt_message)
        
set_api_key_if_not_present("TAVILY_API_KEY")

# %%
tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"],
)
response = tavily_client.search("How do I set up layers in Photoshop?",
                                include_domains=["helpx.adobe.com"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       1 tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"],
#       2 )
#       3 response = tavily_client.search("How do I set up layers in Photoshop?",
#       4                                 include_domains=["helpx.adobe.com"])
# ----> 5 response.pretty_print()
#
# AttributeError: 'dict' object has no attribute 'pretty_print'

# %%
response['results'][2]
# Out:
# {'title': 'Adjustment and fill layers in Photoshop - Adobe Inc.',
#  'url': 'https://helpx.adobe.com/photoshop/using/adjustment-fill-layers.html.html',
#  'content': 'To create a fill layer, do one of the following: Choose Layer > New Fill Layer, and choose an option - Solid Color, Gradient, or Pattern. Name the layer, set layer options, and click OK. Click the New Adjustment Layer button at the bottom of the Layers panel, and choose a fill layer type - Solid Color, Gradient, or Pattern.',
#  'score': 0.61196244,
#  'raw_content': None}
